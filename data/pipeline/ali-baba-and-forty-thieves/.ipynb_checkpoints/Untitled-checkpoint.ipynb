# %%
import pandas as pd
df = pd.read_csv('ali-baba-and-forty-thieves.actions_args.csv')
df
# Out:
#     sentence_id  verb_id        verb  verb_start_byte  verb_end_byte  \
# 0             2        0     marries               51             58
# 1             2        1     becomes               79             86
# 2             2        2    building               99            107
# 3             2        3     marries              150            157
# 4             3        1  collecting               28             38
# ..          ...      ...         ...              ...            ...
# 78           37        2       tried               74             79
# 79           37        3        kill               83             87
# 80           37        4       gives               96            101
# 81           37        5     marries              127            134
# 82           38        1        left               17             21
#
#     verb_start_byte_text  verb_end_byte_text subj_coref_ids  subj_start_byte  \
# 0                    174                 181              2             33.0
# 1                    202                 209              2             33.0
# 2                    222                 230              2             33.0
# 3                    273                 280              1            141.0
# 4                    366                 376              1              8.0
# ..                   ...                 ...            ...              ...
# 78                  4571                4576             55             64.0
# 79                  4580                4584             55             64.0
# 80                  4593                4598              1             93.0
# 81                  4624                4631              1             93.0
# 82                  4665                4669              1              0.0
#
#     subj_end_byte  subj_start_byte_text  subj_end_byte_text dobj_coref_ids  \
# 0            50.0                 156.0               173.0             11
# 1            50.0                 156.0               173.0            NaN
# 2            50.0                 156.0               173.0           10,8
# 3           149.0                 264.0               272.0             13
# 4            16.0                 346.0               354.0            NaN
# ..            ...                   ...                 ...            ...
# 78           73.0                4561.0              4570.0              1
# 79           73.0                4561.0              4570.0              1
# 80           95.0                4590.0              4592.0              4
# 81           95.0                4590.0              4592.0            NaN
# 82            8.0                4648.0              4656.0            NaN
#
#     dobj_start_byte  dobj_end_byte  dobj_start_byte_text  dobj_end_byte_text  \
# 0              59.0           74.0                 182.0               197.0
# 1              87.0           97.0                 210.0               220.0
# 2             108.0          134.0                 231.0               257.0
# 3             158.0          170.0                 281.0               293.0
# 4              51.0           59.0                 389.0               397.0
# ..              ...            ...                   ...                 ...
# 78             80.0           91.0                4577.0              4588.0
# 79             88.0           91.0                4585.0              4588.0
# 80            102.0          110.0                4599.0              4607.0
# 81            135.0          138.0                4632.0              4635.0
# 82             22.0          105.0                4670.0              4753.0
#
#    supersense_category  event_label
# 0          verb.social            1
# 1          verb.change            1
# 2     verb.consumption            1
# 3          verb.social            1
# 4         verb.contact            1
# ..                 ...          ...
# 78         verb.social            1
# 79        verb.contact            1
# 80     verb.possession            1
# 81         verb.social            1
# 82      verb.cognition            1
#
# [83 rows x 19 columns]

# %%
srl[0]['verbs']
# Out:
# [{'verb': 'takes',
#   'description': '[ARG1: The story] [V: takes] [ARG2: place] [ARGM-LOC: in Baghdad] [ARGM-TMP: during the Abbasid era] .',
#   'tags': ['B-ARG1',
#    'I-ARG1',
#    'B-V',
#    'B-ARG2',
#    'B-ARGM-LOC',
#    'I-ARGM-LOC',
#    'B-ARGM-TMP',
#    'I-ARGM-TMP',
#    'I-ARGM-TMP',
#    'I-ARGM-TMP',
#    'O']}]

# %%
adobj_start_bytes = []
adobj_end_bytes = []
offsets = []
for idx in range(df.shape[0]):
    row = df.iloc[idx]
    s_id,v_id = row['sentence_id'], row['verb_id']
    token_start_end_bytes = get_tokens_start_end_bytes(srl[s_id]['words'], sentences[s_id])
    sentence, verb = sentences[s_id], srl[s_id]['verbs'][v_id]
    dobj_end = row['dobj_end_byte']
    tags = verb['tags']
    adobj_start_byte, adobj_end_byte = None,None
    
    start_fixed = False
    for i, tag in enumerate(tags):        
        #if it's a modifier argument after the verb, we add modifier argument columns
        if check_M_arg(tag) and token_start_end_bytes[i]['start_byte']>dobj_end:
            if not start_fixed:
                adobj_start_byte, adobj_end_byte = token_start_end_bytes[i]['start_byte'], token_start_end_bytes[i]['end_byte']
                start_fixed = True
            else:
                adobj_end_byte = token_start_end_bytes[i]['end_byte']

            j=i+1
            while check_M_arg(tags[j]):
                adobj_end_byte = token_start_end_bytes[j]['end_byte']
                j+=1
                
    adobj_start_bytes.append(adobj_start_byte)
    adobj_end_bytes.append(adobj_end_byte)
    if adobj_start_byte:
        offsets.append(row['subj_start_byte_text']-row['subj_start_byte'])
    else:
        offsets.append(None)
            
                
df['adobj_start_bytes'] = adobj_start_bytes
df['adobj_end_bytes'] = adobj_end_bytes

            
            
            
#             arg_token_start_end_bytes.append((tokens_start_end_bytes[i]['start_byte'], tokens_start_end_bytes[i]['end_byte']))
#             tokens.append(words[i])
#             j = i + 1
#             while (j < len(verb['tags'])) and check_I_arg(verb['tags'][j]):
#                 tokens.append(words[j])
#                 arg_token_start_end_bytes.append((tokens_start_end_bytes[j]['start_byte'], tokens_start_end_bytes[j]['end_byte']))
#                 j += 1
#             # Get start and end bytes of tokens
#             start_byte = tokens_start_end_bytes[i]['start_byte']
#             end_byte = tokens_start_end_bytes[j-1]['end_byte']
    
#     print(token_start_end_bytes)
# Out:
# in the forest,
# himself,
# to weigh this new wealth of gold coins.
# to find out what Ali is using them for, as she is curious to know what kind of grain her impoverished brother-in-law needs to measure.
# there,
# so that no one will be suspicious.
# without anyone asking awkward questions.
# back together.
# by marking all the houses in the neighborhood with a similar marking.
# by marking all the houses in the neighborhood with a similar marking.
# by making similar chips in all the other doorsteps.
# as well.
# killing the thirty-seven thieves in their oil jars by pouring boiling oil on them.
# killing the thirty-seven thieves in their oil jars by pouring boiling oil on them.
# by pouring boiling oil on them.
# at Ali Baba's house.
# with a dagger for the diners
# to his son.

# %%
import re
# SRL Argument Functions
def check_B_arg(text: str):
    return re.search(r'B-ARG\d+', text) is not None

def check_I_arg(text: str):
    return re.search(r'I-ARG\d+', text) is not None

def check_arg(text: str):
    return re.search(r'ARG\d+', text) is not None

def check_verb(text: str):
    return re.search(r'\w-V', text) is not None

def check_M_arg(text: str):
    return re.search(r'\D-ARGM\D', text)

# %%
check_B_arg(sentence[0])
# Out:
# False

# %%
sentence[0]
# Out:
# 'The story takes place in Baghdad during the Abbasid era. '

# %%
re.search(r'\D-ARGM\D', srl[0]['verbs'][0]['tags'][4])
# Out:
# <re.Match object; span=(0, 7), match='B-ARGM-'>

# %%
srl[0]['verbs'][0]['tags']
# Out:
# ['B-ARG1',
#  'I-ARG1',
#  'B-V',
#  'B-ARG2',
#  'B-ARGM-LOC',
#  'I-ARGM-LOC',
#  'B-ARGM-TMP',
#  'I-ARGM-TMP',
#  'I-ARGM-TMP',
#  'I-ARGM-TMP',
#  'O']

# %%
srl[0]
# Out:
# {'verbs': [{'verb': 'takes',
#    'description': '[ARG1: The story] [V: takes] [ARG2: place] [ARGM-LOC: in Baghdad] [ARGM-TMP: during the Abbasid era] .',
#    'tags': ['B-ARG1',
#     'I-ARG1',
#     'B-V',
#     'B-ARG2',
#     'B-ARGM-LOC',
#     'I-ARGM-LOC',
#     'B-ARGM-TMP',
#     'I-ARGM-TMP',
#     'I-ARGM-TMP',
#     'I-ARGM-TMP',
#     'O']}],
#  'words': ['The',
#   'story',
#   'takes',
#   'place',
#   'in',
#   'Baghdad',
#   'during',
#   'the',
#   'Abbasid',
#   'era',
#   '.']}

# %%
def get_tokens_start_end_bytes(tokens, sentence):
    token_start_end_bytes_sentence = []

    s = 0
    for i, token in enumerate(tokens):
        token_start_end_bytes = {}

        token_start_end_bytes['token'] = token
        token_start_end_bytes['i'] = i

        start_byte = s
        end_byte = s + len(token)

        if sentence[start_byte] == ' ':
            start_byte += 1
            end_byte += 1

        #print(start_byte, end_byte)
        #print(sentence[start_byte])
        #print(sentence[end_byte])
        #print("mapping :", token, sentence[start_byte:end_byte])
        #print("\n")

        if token != sentence[start_byte:end_byte]:
            print('Incorrect mapping of token to sentence bytes.')
            print(i, token, sentence[start_byte:end_byte])

        token_start_end_bytes['start_byte'] = start_byte
        token_start_end_bytes['end_byte'] = end_byte

        token_start_end_bytes_sentence.append(token_start_end_bytes)

        s = end_byte

    return token_start_end_bytes_sentence

# %%
import json
with open('ali-baba-and-forty-thieves.srl.json') as json_data:
    srl = json.load(json_data)
srl
# Out:
# [{'verbs': [{'verb': 'takes',
#     'description': '[ARG1: The story] [V: takes] [ARG2: place] [ARGM-LOC: in Baghdad] [ARGM-TMP: during the Abbasid era] .',
#     'tags': ['B-ARG1',
#      'I-ARG1',
#      'B-V',
#      'B-ARG2',
#      'B-ARGM-LOC',
#      'I-ARGM-LOC',
#      'B-ARGM-TMP',
#      'I-ARGM-TMP',
#      'I-ARGM-TMP',
#      'I-ARGM-TMP',
#      'O']}],
#   'words': ['The',
#    'story',
#    'takes',
#    'place',
#    'in',
#    'Baghdad',
#    'during',
#    'the',
#    'Abbasid',
#    'era',
#    '.']},
#  {'verbs': [{'verb': 'are',
#     'description': '[ARG1: Ali Baba and his elder brother Cassim] [V: are] [ARG2: the sons of a merchant] .',
#     'tags': ['B-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'B-V',
#      'B-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'O']}],
#   'words': ['Ali',
#    'Baba',
#    'and',
#    'his',
#    'elder',
#    'brother',
#    'Cassim',
#    'are',
#    'the',
#    'sons',
#    'of',
#    'a',
#    'merchant',
#    '.']},
#  {'verbs': [{'verb': 'marries',
#     'description': "[ARGM-TMP: After the death of their father] , [ARG1: the greedy Cassim] [V: marries] [ARG2: a wealthy woman] and becomes well - to - do , building on their father 's business - but Ali Baba marries a poor woman and settles into the trade of a woodcutter .",
#     'tags': ['B-ARGM-TMP',
#      'I-ARGM-TMP',
#      'I-ARGM-TMP',
#      'I-ARGM-TMP',
#      'I-ARGM-TMP',
#      'I-ARGM-TMP',
#      'O',
#      'B-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'B-V',
#      'B-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O']},
#    {'verb': 'becomes',
#     'description': "[ARGM-TMP: After the death of their father] , [ARG1: the greedy Cassim] marries a wealthy woman and [V: becomes] [ARG2: well - to - do] , building on their father 's business - but Ali Baba marries a poor woman and settles into the trade of a woodcutter .",
#     'tags': ['B-ARGM-TMP',
#      'I-ARGM-TMP',
#      'I-ARGM-TMP',
#      'I-ARGM-TMP',
#      'I-ARGM-TMP',
#      'I-ARGM-TMP',
#      'O',
#      'B-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'B-V',
#      'B-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O']},
#    {'verb': 'building',
#     'description': "After the death of their father , [ARG0: the greedy Cassim] marries a wealthy woman and becomes well - to - do , [V: building] [ARG1: on their father 's business] - but Ali Baba marries a poor woman and settles into the trade of a woodcutter .",
#     'tags': ['O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'B-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'B-V',
#      'B-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O']},
#    {'verb': 'marries',
#     'description': "After the death of their father , the greedy Cassim marries a wealthy woman and becomes well - to - do , building on their father 's business - but [ARG1: Ali Baba] [V: marries] [ARG2: a poor woman] and settles into the trade of a woodcutter .",
#     'tags': ['O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'B-ARG1',
#      'I-ARG1',
#      'B-V',
#      'B-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O']},
#    {'verb': 'settles',
#     'description': "[ARGM-TMP: After the death of their father] , the greedy Cassim marries a wealthy woman and becomes well - to - do , building on their father 's business - but [ARG0: Ali Baba] marries a poor woman and [V: settles] [ARGM-DIR: into the trade of a woodcutter] .",
#     'tags': ['B-ARGM-TMP',
#      'I-ARGM-TMP',
#      'I-ARGM-TMP',
#      'I-ARGM-TMP',
#      'I-ARGM-TMP',
#      'I-ARGM-TMP',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'B-ARG0',
#      'I-ARG0',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'B-V',
#      'B-ARGM-DIR',
#      'I-ARGM-DIR',
#      'I-ARGM-DIR',
#      'I-ARGM-DIR',
#      'I-ARGM-DIR',
#      'I-ARGM-DIR',
#      'O']}],
#   'words': ['After',
#    'the',
#    'death',
#    'of',
#    'their',
#    'father',
#    ',',
#    'the',
#    'greedy',
#    'Cassim',
#    'marries',
#    'a',
#    'wealthy',
#    'woman',
#    'and',
#    'becomes',
#    'well',
#    '-',
#    'to',
#    '-',
#    'do',
#    ',',
#    'building',
#    'on',
#    'their',
#    'father',
#    "'s",
#    'business',
#    '-',
#    'but',
#    'Ali',
#    'Baba',
#    'marries',
#    'a',
#    'poor',
#    'woman',
#    'and',
#    'settles',
#    'into',
#    'the',
#    'trade',
#    'of',
#    'a',
#    'woodcutter',
#    '.']},
#  {'verbs': [{'verb': 'is',
#     'description': '[ARG1: One day Ali Baba] [V: is] [ARG2: at work collecting and cutting firewood in the forest] , and he happens to overhear a group of forty thieves visiting their treasure store .',
#     'tags': ['B-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'B-V',
#      'B-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O']},
#    {'verb': 'collecting',
#     'description': 'One day [ARG0: Ali Baba] is at work [V: collecting] and cutting [ARG1: firewood] [ARGM-LOC: in the forest] , and he happens to overhear a group of forty thieves visiting their treasure store .',
#     'tags': ['O',
#      'O',
#      'B-ARG0',
#      'I-ARG0',
#      'O',
#      'O',
#      'O',
#      'B-V',
#      'O',
#      'O',
#      'B-ARG1',
#      'B-ARGM-LOC',
#      'I-ARGM-LOC',
#      'I-ARGM-LOC',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O']},
#    {'verb': 'cutting',
#     'description': 'One day Ali Baba is at work collecting and [V: cutting] [ARG1: firewood] [ARGM-LOC: in the forest] , and he happens to overhear a group of forty thieves visiting their treasure store .',
#     'tags': ['O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'B-V',
#      'B-ARG1',
#      'B-ARGM-LOC',
#      'I-ARGM-LOC',
#      'I-ARGM-LOC',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O']},
#    {'verb': 'happens',
#     'description': 'One day Ali Baba is at work collecting and cutting firewood in the forest , and he [V: happens] [ARG1: to overhear a group of forty thieves visiting their treasure store] .',
#     'tags': ['O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'B-V',
#      'B-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'O']},
#    {'verb': 'overhear',
#     'description': 'One day Ali Baba is at work collecting and cutting firewood in the forest , and [ARG0: he] happens to [V: overhear] [ARG1: a group of forty thieves visiting their treasure store] .',
#     'tags': ['O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'B-ARG0',
#      'O',
#      'O',
#      'B-V',
#      'B-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'O']},
#    {'verb': 'visiting',
#     'description': 'One day Ali Baba is at work collecting and cutting firewood in the forest , and he happens to overhear a group of [ARG0: forty thieves] [V: visiting] [ARG1: their treasure store] .',
#     'tags': ['O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'B-ARG0',
#      'I-ARG0',
#      'B-V',
#      'B-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'O']}],
#   'words': ['One',
#    'day',
#    'Ali',
#    'Baba',
#    'is',
#    'at',
#    'work',
#    'collecting',
#    'and',
#    'cutting',
#    'firewood',
#    'in',
#    'the',
#    'forest',
#    ',',
#    'and',
#    'he',
#    'happens',
#    'to',
#    'overhear',
#    'a',
#    'group',
#    'of',
#    'forty',
#    'thieves',
#    'visiting',
#    'their',
#    'treasure',
#    'store',
#    '.']},
#  {'verbs': [{'verb': 'is',
#     'description': '[ARG1: The treasure] [V: is] [ARG2: in a cave , the mouth of which is sealed by magic] .',
#     'tags': ['B-ARG1',
#      'I-ARG1',
#      'B-V',
#      'B-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'O']},
#    {'verb': 'is',
#     'description': 'The treasure is in a cave , the mouth of which [V: is] sealed by magic .',
#     'tags': ['O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'B-V',
#      'O',
#      'O',
#      'O',
#      'O']},
#    {'verb': 'sealed',
#     'description': 'The treasure is in a cave , [ARG1: the mouth of which] is [V: sealed] [ARG0: by magic] .',
#     'tags': ['O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'B-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'O',
#      'B-V',
#      'B-ARG0',
#      'I-ARG0',
#      'O']}],
#   'words': ['The',
#    'treasure',
#    'is',
#    'in',
#    'a',
#    'cave',
#    ',',
#    'the',
#    'mouth',
#    'of',
#    'which',
#    'is',
#    'sealed',
#    'by',
#    'magic',
#    '.']},
#  {'verbs': [{'verb': 'opens',
#     'description': '[ARG2: It] [V: opens] [ARG1: on the words " Open , Simsim " , and seals itself on the words " Close , Simsim "] .',
#     'tags': ['B-ARG2',
#      'B-V',
#      'B-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'O']},
#    {'verb': 'seals',
#     'description': '[ARG0: It] opens on the words " Open , Simsim " , and [V: seals] [ARG1: itself] [ARG2: on the words " Close , Simsim "] .',
#     'tags': ['B-ARG0',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'B-V',
#      'B-ARG1',
#      'B-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'O']}],
#   'words': ['It',
#    'opens',
#    'on',
#    'the',
#    'words',
#    '"',
#    'Open',
#    ',',
#    'Simsim',
#    '"',
#    ',',
#    'and',
#    'seals',
#    'itself',
#    'on',
#    'the',
#    'words',
#    '"',
#    'Close',
#    ',',
#    'Simsim',
#    '"',
#    '.']},
#  {'verbs': [{'verb': 'are',
#     'description': 'When the thieves [V: are] gone , Ali Baba enters the cave himself , and takes some of the treasure home .',
#     'tags': ['O',
#      'O',
#      'O',
#      'B-V',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O']},
#    {'verb': 'gone',
#     'description': '[ARGM-TMP: When] [ARG1: the thieves] are [V: gone] , Ali Baba enters the cave himself , and takes some of the treasure home .',
#     'tags': ['B-ARGM-TMP',
#      'B-ARG1',
#      'I-ARG1',
#      'O',
#      'B-V',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O']},
#    {'verb': 'enters',
#     'description': '[ARGM-TMP: When the thieves are gone] , [ARG0: Ali Baba] [V: enters] [ARG1: the cave] [ARGM-REC: himself] , and takes some of the treasure home .',
#     'tags': ['B-ARGM-TMP',
#      'I-ARGM-TMP',
#      'I-ARGM-TMP',
#      'I-ARGM-TMP',
#      'I-ARGM-TMP',
#      'O',
#      'B-ARG0',
#      'I-ARG0',
#      'B-V',
#      'B-ARG1',
#      'I-ARG1',
#      'B-ARGM-REC',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O']},
#    {'verb': 'takes',
#     'description': '[ARGM-TMP: When the thieves are gone] , [ARG0: Ali Baba] enters the cave himself , and [V: takes] [ARG1: some of the treasure] [ARG2: home] .',
#     'tags': ['B-ARGM-TMP',
#      'I-ARGM-TMP',
#      'I-ARGM-TMP',
#      'I-ARGM-TMP',
#      'I-ARGM-TMP',
#      'O',
#      'B-ARG0',
#      'I-ARG0',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'B-V',
#      'B-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'B-ARG2',
#      'O']}],
#   'words': ['When',
#    'the',
#    'thieves',
#    'are',
#    'gone',
#    ',',
#    'Ali',
#    'Baba',
#    'enters',
#    'the',
#    'cave',
#    'himself',
#    ',',
#    'and',
#    'takes',
#    'some',
#    'of',
#    'the',
#    'treasure',
#    'home',
#    '.']},
#  {'verbs': [{'verb': 'borrows',
#     'description': "[ARG0: Ali Baba] [V: borrows] [ARG1: his sister - in - law 's scales] [ARGM-PRP: to weigh this new wealth of gold coins] .",
#     'tags': ['B-ARG0',
#      'I-ARG0',
#      'B-V',
#      'B-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'B-ARGM-PRP',
#      'I-ARGM-PRP',
#      'I-ARGM-PRP',
#      'I-ARGM-PRP',
#      'I-ARGM-PRP',
#      'I-ARGM-PRP',
#      'I-ARGM-PRP',
#      'I-ARGM-PRP',
#      'O']},
#    {'verb': 'weigh',
#     'description': "[ARG0: Ali Baba] borrows his sister - in - law 's scales to [V: weigh] [ARG1: this new wealth of gold coins] .",
#     'tags': ['B-ARG0',
#      'I-ARG0',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'B-V',
#      'B-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'O']}],
#   'words': ['Ali',
#    'Baba',
#    'borrows',
#    'his',
#    'sister',
#    '-',
#    'in',
#    '-',
#    'law',
#    "'s",
#    'scales',
#    'to',
#    'weigh',
#    'this',
#    'new',
#    'wealth',
#    'of',
#    'gold',
#    'coins',
#    '.']},
#  {'verbs': [{'verb': 'puts',
#     'description': '[R-ARG0: Unbeknownst to Ali] , [ARG0: she] [V: puts] [ARG1: a blob of wax] [ARG2: in the scales] [ARGM-PRP: to find out what Ali is using them for] , [ARGM-ADV: as she is curious to know what kind of grain her impoverished brother - in - law needs to measure] .',
#     'tags': ['B-R-ARG0',
#      'I-R-ARG0',
#      'I-R-ARG0',
#      'O',
#      'B-ARG0',
#      'B-V',
#      'B-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'B-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'B-ARGM-PRP',
#      'I-ARGM-PRP',
#      'I-ARGM-PRP',
#      'I-ARGM-PRP',
#      'I-ARGM-PRP',
#      'I-ARGM-PRP',
#      'I-ARGM-PRP',
#      'I-ARGM-PRP',
#      'I-ARGM-PRP',
#      'O',
#      'B-ARGM-ADV',
#      'I-ARGM-ADV',
#      'I-ARGM-ADV',
#      'I-ARGM-ADV',
#      'I-ARGM-ADV',
#      'I-ARGM-ADV',
#      'I-ARGM-ADV',
#      'I-ARGM-ADV',
#      'I-ARGM-ADV',
#      'I-ARGM-ADV',
#      'I-ARGM-ADV',
#      'I-ARGM-ADV',
#      'I-ARGM-ADV',
#      'I-ARGM-ADV',
#      'I-ARGM-ADV',
#      'I-ARGM-ADV',
#      'I-ARGM-ADV',
#      'I-ARGM-ADV',
#      'I-ARGM-ADV',
#      'I-ARGM-ADV',
#      'O']},
#    {'verb': 'find',
#     'description': 'Unbeknownst to Ali , she puts a blob of wax in the scales to [V: find] out [ARG1: what Ali is using them for] , as she is curious to know what kind of grain her impoverished brother - in - law needs to measure .',
#     'tags': ['O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'B-V',
#      'O',
#      'B-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O']},
#    {'verb': 'is',
#     'description': 'Unbeknownst to Ali , she puts a blob of wax in the scales to find out what Ali [V: is] using them for , as she is curious to know what kind of grain her impoverished brother - in - law needs to measure .',
#     'tags': ['O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'B-V',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O']},
#    {'verb': 'using',
#     'description': 'Unbeknownst to Ali , she puts a blob of wax in the scales to find out what [ARG0: Ali] is [V: using] [ARG1: them] [ARG2: for] , as she is curious to know what kind of grain her impoverished brother - in - law needs to measure .',
#     'tags': ['O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'B-ARG0',
#      'O',
#      'B-V',
#      'B-ARG1',
#      'B-ARG2',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O']},
#    {'verb': 'is',
#     'description': 'Unbeknownst to Ali , she puts a blob of wax in the scales to find out what Ali is using them for , as [ARG1: she] [V: is] [ARG2: curious to know what kind of grain her impoverished brother - in - law needs to measure] .',
#     'tags': ['O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'B-ARG1',
#      'B-V',
#      'B-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'O']},
#    {'verb': 'know',
#     'description': 'Unbeknownst to Ali , she puts a blob of wax in the scales to find out what Ali is using them for , as [ARG0: she] is curious to [V: know] [ARG1: what kind of grain her impoverished brother - in - law needs to measure] .',
#     'tags': ['O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'B-ARG0',
#      'O',
#      'O',
#      'O',
#      'B-V',
#      'B-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'O']},
#    {'verb': 'needs',
#     'description': 'Unbeknownst to Ali , she puts a blob of wax in the scales to find out what Ali is using them for , as she is curious to know what kind of grain [ARG0: her impoverished brother - in - law] [V: needs] [ARG1: to measure] .',
#     'tags': ['O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'B-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'B-V',
#      'B-ARG1',
#      'I-ARG1',
#      'O']},
#    {'verb': 'measure',
#     'description': 'Unbeknownst to Ali , she puts a blob of wax in the scales to find out what Ali is using them for , as she is curious to know [ARG1: what kind of grain] [ARG0: her impoverished brother - in - law] needs to [V: measure] .',
#     'tags': ['O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'B-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'B-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'O',
#      'O',
#      'B-V',
#      'O']}],
#   'words': ['Unbeknownst',
#    'to',
#    'Ali',
#    ',',
#    'she',
#    'puts',
#    'a',
#    'blob',
#    'of',
#    'wax',
#    'in',
#    'the',
#    'scales',
#    'to',
#    'find',
#    'out',
#    'what',
#    'Ali',
#    'is',
#    'using',
#    'them',
#    'for',
#    ',',
#    'as',
#    'she',
#    'is',
#    'curious',
#    'to',
#    'know',
#    'what',
#    'kind',
#    'of',
#    'grain',
#    'her',
#    'impoverished',
#    'brother',
#    '-',
#    'in',
#    '-',
#    'law',
#    'needs',
#    'to',
#    'measure',
#    '.']},
#  {'verbs': [{'verb': 'finds',
#     'description': "[R-ARG0: To her shock] , [ARG0: she] [V: finds] [ARG1: a gold coin sticking to the scales] and tells her husband , Ali Baba 's rich and greedy brother , Cassim .",
#     'tags': ['B-R-ARG0',
#      'I-R-ARG0',
#      'I-R-ARG0',
#      'O',
#      'B-ARG0',
#      'B-V',
#      'B-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O']},
#    {'verb': 'tells',
#     'description': "[R-ARG0: To her shock] , [ARG0: she] finds a gold coin sticking to the scales and [V: tells] [ARG2: her husband , Ali Baba 's rich and greedy brother , Cassim] .",
#     'tags': ['B-R-ARG0',
#      'I-R-ARG0',
#      'I-R-ARG0',
#      'O',
#      'B-ARG0',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'B-V',
#      'B-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'O']}],
#   'words': ['To',
#    'her',
#    'shock',
#    ',',
#    'she',
#    'finds',
#    'a',
#    'gold',
#    'coin',
#    'sticking',
#    'to',
#    'the',
#    'scales',
#    'and',
#    'tells',
#    'her',
#    'husband',
#    ',',
#    'Ali',
#    'Baba',
#    "'s",
#    'rich',
#    'and',
#    'greedy',
#    'brother',
#    ',',
#    'Cassim',
#    '.']},
#  {'verbs': [{'verb': 'is',
#     'description': 'Under pressure from his brother , Ali Baba [V: is] forced to reveal the secret of the cave .',
#     'tags': ['O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'B-V',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O']},
#    {'verb': 'forced',
#     'description': '[ARG1: Under pressure from his brother , Ali Baba] is [V: forced] [ARG2: to reveal the secret of the cave] .',
#     'tags': ['B-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'O',
#      'B-V',
#      'B-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'O']},
#    {'verb': 'reveal',
#     'description': 'Under pressure from his brother , [ARG0: Ali Baba] is forced to [V: reveal] [ARG1: the secret of the cave] .',
#     'tags': ['O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'B-ARG0',
#      'I-ARG0',
#      'O',
#      'O',
#      'O',
#      'B-V',
#      'B-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'O']}],
#   'words': ['Under',
#    'pressure',
#    'from',
#    'his',
#    'brother',
#    ',',
#    'Ali',
#    'Baba',
#    'is',
#    'forced',
#    'to',
#    'reveal',
#    'the',
#    'secret',
#    'of',
#    'the',
#    'cave',
#    '.']},
#  {'verbs': [{'verb': 'goes',
#     'description': '[ARG1: Cassim] [V: goes] [ARG4: to the cave] and enters with the magic words , but in his greed and excitement over the treasures forgets the magic words to get back out again .',
#     'tags': ['B-ARG1',
#      'B-V',
#      'B-ARG4',
#      'I-ARG4',
#      'I-ARG4',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O']},
#    {'verb': 'enters',
#     'description': '[ARG0: Cassim] goes to the cave and [V: enters] [ARG1: with the magic words] , but in his greed and excitement over the treasures forgets the magic words to get back out again .',
#     'tags': ['B-ARG0',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'B-V',
#      'B-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O']},
#    {'verb': 'forgets',
#     'description': 'Cassim goes to the cave and enters with the magic words , but [ARGM-MNR: in his greed and excitement over the treasures] [V: forgets] [ARG1: the magic words] [ARGM-PRP: to get back out again] .',
#     'tags': ['O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'B-ARGM-MNR',
#      'I-ARGM-MNR',
#      'I-ARGM-MNR',
#      'I-ARGM-MNR',
#      'I-ARGM-MNR',
#      'I-ARGM-MNR',
#      'I-ARGM-MNR',
#      'I-ARGM-MNR',
#      'B-V',
#      'B-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'B-ARGM-PRP',
#      'I-ARGM-PRP',
#      'I-ARGM-PRP',
#      'I-ARGM-PRP',
#      'I-ARGM-PRP',
#      'O']},
#    {'verb': 'get',
#     'description': 'Cassim goes to the cave and enters with the magic words , but in his greed and excitement over the treasures forgets the magic words to [V: get] [ARG2: back out] [ARGM-TMP: again] .',
#     'tags': ['O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'B-V',
#      'B-ARG2',
#      'I-ARG2',
#      'B-ARGM-TMP',
#      'O']}],
#   'words': ['Cassim',
#    'goes',
#    'to',
#    'the',
#    'cave',
#    'and',
#    'enters',
#    'with',
#    'the',
#    'magic',
#    'words',
#    ',',
#    'but',
#    'in',
#    'his',
#    'greed',
#    'and',
#    'excitement',
#    'over',
#    'the',
#    'treasures',
#    'forgets',
#    'the',
#    'magic',
#    'words',
#    'to',
#    'get',
#    'back',
#    'out',
#    'again',
#    '.']},
#  {'verbs': [{'verb': 'find',
#     'description': '[ARG0: The thieves] [V: find] [ARG1: him] [ARGM-LOC: there] , and kill him .',
#     'tags': ['B-ARG0',
#      'I-ARG0',
#      'B-V',
#      'B-ARG1',
#      'B-ARGM-LOC',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O']},
#    {'verb': 'kill',
#     'description': '[ARG0: The thieves] find him there , and [V: kill] [ARG1: him] .',
#     'tags': ['B-ARG0',
#      'I-ARG0',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'B-V',
#      'B-ARG1',
#      'O']}],
#   'words': ['The',
#    'thieves',
#    'find',
#    'him',
#    'there',
#    ',',
#    'and',
#    'kill',
#    'him',
#    '.']},
#  {'verbs': [{'verb': 'does',
#     'description': 'When his brother [V: does] not come back , Ali Baba goes to the cave to look for him , and finds the body , quartered and with each piece displayed just inside the entrance of the cave to discourage any similar attempts in the future .',
#     'tags': ['O',
#      'O',
#      'O',
#      'B-V',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O']},
#    {'verb': 'come',
#     'description': '[ARGM-TMP: When] [ARG1: his brother] does [ARGM-NEG: not] [V: come] [ARGM-DIR: back] , Ali Baba goes to the cave to look for him , and finds the body , quartered and with each piece displayed just inside the entrance of the cave to discourage any similar attempts in the future .',
#     'tags': ['B-ARGM-TMP',
#      'B-ARG1',
#      'I-ARG1',
#      'O',
#      'B-ARGM-NEG',
#      'B-V',
#      'B-ARGM-DIR',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O']},
#    {'verb': 'goes',
#     'description': '[ARGM-TMP: When his brother does not come back] , [ARG0: Ali Baba] [V: goes] [ARG4: to the cave] [ARGM-PRP: to look for him] , and finds the body , quartered and with each piece displayed just inside the entrance of the cave to discourage any similar attempts in the future .',
#     'tags': ['B-ARGM-TMP',
#      'I-ARGM-TMP',
#      'I-ARGM-TMP',
#      'I-ARGM-TMP',
#      'I-ARGM-TMP',
#      'I-ARGM-TMP',
#      'I-ARGM-TMP',
#      'O',
#      'B-ARG0',
#      'I-ARG0',
#      'B-V',
#      'B-ARG4',
#      'I-ARG4',
#      'I-ARG4',
#      'B-ARGM-PRP',
#      'I-ARGM-PRP',
#      'I-ARGM-PRP',
#      'I-ARGM-PRP',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O']},
#    {'verb': 'look',
#     'description': 'When his brother does not come back , [ARG0: Ali Baba] goes to the cave to [V: look] [ARG1: for him] , and finds the body , quartered and with each piece displayed just inside the entrance of the cave to discourage any similar attempts in the future .',
#     'tags': ['O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'B-ARG0',
#      'I-ARG0',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'B-V',
#      'B-ARG1',
#      'I-ARG1',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O']},
#    {'verb': 'finds',
#     'description': '[ARGM-TMP: When his brother does not come back] , [ARG0: Ali Baba] goes to the cave to look for him , and [V: finds] [ARG1: the body , quartered and with each piece displayed just inside the entrance of the cave to discourage any similar attempts in the future] .',
#     'tags': ['B-ARGM-TMP',
#      'I-ARGM-TMP',
#      'I-ARGM-TMP',
#      'I-ARGM-TMP',
#      'I-ARGM-TMP',
#      'I-ARGM-TMP',
#      'I-ARGM-TMP',
#      'O',
#      'B-ARG0',
#      'I-ARG0',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'B-V',
#      'B-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'O']},
#    {'verb': 'quartered',
#     'description': 'When his brother does not come back , Ali Baba goes to the cave to look for him , and finds [ARG1: the body] , [V: quartered] and with each piece displayed just inside the entrance of the cave to discourage any similar attempts in the future .',
#     'tags': ['O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'B-ARG1',
#      'I-ARG1',
#      'O',
#      'B-V',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O']},
#    {'verb': 'displayed',
#     'description': 'When his brother does not come back , Ali Baba goes to the cave to look for him , and finds [ARG1: the body , quartered and with each piece] [V: displayed] [ARG2: just inside the entrance of the cave] [ARGM-PRP: to discourage any similar attempts in the future] .',
#     'tags': ['O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'B-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'B-V',
#      'B-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'B-ARGM-PRP',
#      'I-ARGM-PRP',
#      'I-ARGM-PRP',
#      'I-ARGM-PRP',
#      'I-ARGM-PRP',
#      'I-ARGM-PRP',
#      'I-ARGM-PRP',
#      'I-ARGM-PRP',
#      'O']},
#    {'verb': 'discourage',
#     'description': 'When his brother does not come back , Ali Baba goes to the cave to look for him , and finds the body , quartered and with each piece displayed just inside the entrance of the cave to [V: discourage] [ARG1: any similar attempts in the future] .',
#     'tags': ['O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'B-V',
#      'B-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'O']}],
#   'words': ['When',
#    'his',
#    'brother',
#    'does',
#    'not',
#    'come',
#    'back',
#    ',',
#    'Ali',
#    'Baba',
#    'goes',
#    'to',
#    'the',
#    'cave',
#    'to',
#    'look',
#    'for',
#    'him',
#    ',',
#    'and',
#    'finds',
#    'the',
#    'body',
#    ',',
#    'quartered',
#    'and',
#    'with',
#    'each',
#    'piece',
#    'displayed',
#    'just',
#    'inside',
#    'the',
#    'entrance',
#    'of',
#    'the',
#    'cave',
#    'to',
#    'discourage',
#    'any',
#    'similar',
#    'attempts',
#    'in',
#    'the',
#    'future',
#    '.']},
#  {'verbs': [{'verb': 'brings',
#     'description': "[ARG0: Ali Baba] [V: brings] [ARG1: the body] [ARG2: home , where he entrusts Morgiana , a clever slave - girl in Cassim 's household] [ARG4: , with the task of making others believe that Cassim has died a natural death] .",
#     'tags': ['B-ARG0',
#      'I-ARG0',
#      'B-V',
#      'B-ARG1',
#      'I-ARG1',
#      'B-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'B-ARG4',
#      'I-ARG4',
#      'I-ARG4',
#      'I-ARG4',
#      'I-ARG4',
#      'I-ARG4',
#      'I-ARG4',
#      'I-ARG4',
#      'I-ARG4',
#      'I-ARG4',
#      'I-ARG4',
#      'I-ARG4',
#      'I-ARG4',
#      'I-ARG4',
#      'I-ARG4',
#      'O']},
#    {'verb': 'entrusts',
#     'description': "Ali Baba brings the body home , [R-ARGM-LOC: where] [ARG0: he] [V: entrusts] [ARG1: Morgiana] , a clever slave - girl in Cassim 's household , with the task of making others believe that Cassim has died a natural death .",
#     'tags': ['O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'B-R-ARGM-LOC',
#      'B-ARG0',
#      'B-V',
#      'B-ARG1',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O']},
#    {'verb': 'making',
#     'description': "Ali Baba brings the body home , where he entrusts Morgiana , a clever slave - girl in Cassim 's household , with the task of [V: making] [ARG1: others believe that Cassim has died a natural death] .",
#     'tags': ['O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'B-V',
#      'B-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'O']},
#    {'verb': 'believe',
#     'description': "Ali Baba brings the body home , where he entrusts Morgiana , a clever slave - girl in Cassim 's household , with the task of making [ARG0: others] [V: believe] [ARG1: that Cassim has died a natural death] .",
#     'tags': ['O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'B-ARG0',
#      'B-V',
#      'B-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'O']},
#    {'verb': 'has',
#     'description': "Ali Baba brings the body home , where he entrusts Morgiana , a clever slave - girl in Cassim 's household , with the task of making others believe that Cassim [V: has] died a natural death .",
#     'tags': ['O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'B-V',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O']},
#    {'verb': 'died',
#     'description': "Ali Baba brings the body home , where he entrusts Morgiana , a clever slave - girl in Cassim 's household , with the task of making others believe that [ARG1: Cassim] has [V: died] [ARGM-PRD: a natural death] .",
#     'tags': ['O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'B-ARG1',
#      'O',
#      'B-V',
#      'B-ARGM-PRD',
#      'I-ARGM-PRD',
#      'I-ARGM-PRD',
#      'O']}],
#   'words': ['Ali',
#    'Baba',
#    'brings',
#    'the',
#    'body',
#    'home',
#    ',',
#    'where',
#    'he',
#    'entrusts',
#    'Morgiana',
#    ',',
#    'a',
#    'clever',
#    'slave',
#    '-',
#    'girl',
#    'in',
#    'Cassim',
#    "'s",
#    'household',
#    ',',
#    'with',
#    'the',
#    'task',
#    'of',
#    'making',
#    'others',
#    'believe',
#    'that',
#    'Cassim',
#    'has',
#    'died',
#    'a',
#    'natural',
#    'death',
#    '.']},
#  {'verbs': [{'verb': 'purchases',
#     'description': "[ARGM-DIS: First] , [ARG0: Morgiana] [V: purchases] [ARG1: medicines] [ARG2: from an apothecary] , telling him that Cassim is gravely ill . Then , she finds an old tailor known as Baba Mustafa whom she pays , blindfolds , and leads to Cassim 's house .",
#     'tags': ['B-ARGM-DIS',
#      'O',
#      'B-ARG0',
#      'B-V',
#      'B-ARG1',
#      'B-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O']},
#    {'verb': 'telling',
#     'description': "First , Morgiana purchases medicines from an apothecary , [V: telling] [ARG2: him] [ARG1: that Cassim is gravely ill] . Then , [ARG0: she] finds an old tailor known as Baba Mustafa whom she pays , blindfolds , and leads to Cassim 's house .",
#     'tags': ['O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'B-V',
#      'B-ARG2',
#      'B-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'O',
#      'O',
#      'O',
#      'B-ARG0',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O']},
#    {'verb': 'is',
#     'description': "First , Morgiana purchases medicines from an apothecary , telling him that [ARG1: Cassim] [V: is] [ARG2: gravely ill] . Then , she finds an old tailor known as Baba Mustafa whom she pays , blindfolds , and leads to Cassim 's house .",
#     'tags': ['O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'B-ARG1',
#      'B-V',
#      'B-ARG2',
#      'I-ARG2',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O']},
#    {'verb': 'finds',
#     'description': "First , Morgiana purchases medicines from an apothecary , telling him that Cassim is gravely ill . [ARGM-TMP: Then] , [ARG0: she] [V: finds] [ARG1: an old tailor known as Baba Mustafa whom she pays , blindfolds , and leads to Cassim 's house] .",
#     'tags': ['O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'B-ARGM-TMP',
#      'O',
#      'B-ARG0',
#      'B-V',
#      'B-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'O']},
#    {'verb': 'known',
#     'description': "First , Morgiana purchases medicines from an apothecary , telling him that Cassim is gravely ill . Then , she finds [ARG1: an old tailor] [V: known] [ARG2: as Baba Mustafa whom she pays , blindfolds] , and leads to Cassim 's house .",
#     'tags': ['O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'B-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'B-V',
#      'B-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O']},
#    {'verb': 'pays',
#     'description': "First , Morgiana purchases medicines from an apothecary , telling him that Cassim is gravely ill . Then , she finds an old tailor known as [ARG1: Baba Mustafa] [R-ARG1: whom] [ARG0: she] [V: pays] , blindfolds , and leads to Cassim 's house .",
#     'tags': ['O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'B-ARG1',
#      'I-ARG1',
#      'B-R-ARG1',
#      'B-ARG0',
#      'B-V',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O']},
#    {'verb': 'leads',
#     'description': "First , Morgiana purchases medicines from an apothecary , telling him that Cassim is gravely ill . Then , she finds an old tailor known [ARG0: as Baba Mustafa] [R-ARG0: whom] she pays , blindfolds , and [V: leads] [ARG4: to Cassim 's house] .",
#     'tags': ['O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'B-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'B-R-ARG0',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'B-V',
#      'B-ARG4',
#      'I-ARG4',
#      'I-ARG4',
#      'I-ARG4',
#      'O']}],
#   'words': ['First',
#    ',',
#    'Morgiana',
#    'purchases',
#    'medicines',
#    'from',
#    'an',
#    'apothecary',
#    ',',
#    'telling',
#    'him',
#    'that',
#    'Cassim',
#    'is',
#    'gravely',
#    'ill',
#    '.',
#    'Then',
#    ',',
#    'she',
#    'finds',
#    'an',
#    'old',
#    'tailor',
#    'known',
#    'as',
#    'Baba',
#    'Mustafa',
#    'whom',
#    'she',
#    'pays',
#    ',',
#    'blindfolds',
#    ',',
#    'and',
#    'leads',
#    'to',
#    'Cassim',
#    "'s",
#    'house',
#    '.']},
#  {'verbs': [{'verb': 'stitches',
#     'description': "[ARGM-LOC: There] , [ARGM-TMP: overnight] , [ARG0: the tailor] [V: stitches] [ARG1: the pieces of Cassims ' body] [ARG2: back together] , [ARGM-PRP: so that no one will be suspicious] .",
#     'tags': ['B-ARGM-LOC',
#      'O',
#      'B-ARGM-TMP',
#      'O',
#      'B-ARG0',
#      'I-ARG0',
#      'B-V',
#      'B-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'B-ARG2',
#      'I-ARG2',
#      'O',
#      'B-ARGM-PRP',
#      'I-ARGM-PRP',
#      'I-ARGM-PRP',
#      'I-ARGM-PRP',
#      'I-ARGM-PRP',
#      'I-ARGM-PRP',
#      'I-ARGM-PRP',
#      'O']},
#    {'verb': 'will',
#     'description': "There , overnight , the tailor stitches the pieces of Cassims ' body back together , so that [ARG1: no] one [V: will] [ARG1: be suspicious] .",
#     'tags': ['O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'B-ARG1',
#      'O',
#      'B-V',
#      'B-ARG1',
#      'I-ARG1',
#      'O']},
#    {'verb': 'be',
#     'description': "There , overnight , the tailor stitches the pieces of Cassims ' body back together , so that [ARG1: no one] [ARGM-MOD: will] [V: be] [ARG2: suspicious] .",
#     'tags': ['O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'B-ARG1',
#      'I-ARG1',
#      'B-ARGM-MOD',
#      'B-V',
#      'B-ARG2',
#      'O']}],
#   'words': ['There',
#    ',',
#    'overnight',
#    ',',
#    'the',
#    'tailor',
#    'stitches',
#    'the',
#    'pieces',
#    'of',
#    'Cassims',
#    "'",
#    'body',
#    'back',
#    'together',
#    ',',
#    'so',
#    'that',
#    'no',
#    'one',
#    'will',
#    'be',
#    'suspicious',
#    '.']},
#  {'verbs': [{'verb': 'are',
#     'description': '[ARG1: Ali and his family] [V: are] [ARG2: able to give Cassim a proper burial without anyone asking awkward questions] .',
#     'tags': ['B-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'B-V',
#      'B-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'O']},
#    {'verb': 'give',
# ...
#      'O']},
#    {'verb': 'escapes',
#     'description': '[ARGM-TMP: When their leader comes to rouse his men] , [ARG0: he] discovers that they are dead , and [V: escapes] .',
#     'tags': ['B-ARGM-TMP',
#      'I-ARGM-TMP',
#      'I-ARGM-TMP',
#      'I-ARGM-TMP',
#      'I-ARGM-TMP',
#      'I-ARGM-TMP',
#      'I-ARGM-TMP',
#      'I-ARGM-TMP',
#      'O',
#      'B-ARG0',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'B-V',
#      'O']}],
#   'words': ['When',
#    'their',
#    'leader',
#    'comes',
#    'to',
#    'rouse',
#    'his',
#    'men',
#    ',',
#    'he',
#    'discovers',
#    'that',
#    'they',
#    'are',
#    'dead',
#    ',',
#    'and',
#    'escapes',
#    '.']},
#  {'verbs': [{'verb': 'exact',
#     'description': "To [V: exact] [ARG1: revenge] , after some time the thief establishes himself as a merchant , [ARG0: befriends] Ali Baba 's son ( who is now in charge of the late Cassim 's business ) , and is invited to dinner at Ali Baba 's house .",
#     'tags': ['O',
#      'B-V',
#      'B-ARG1',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'B-ARG0',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O']},
#    {'verb': 'establishes',
#     'description': "To exact revenge , [ARGM-TMP: after some time] [ARG0: the thief] [V: establishes] [ARG1: himself] [ARG2: as a merchant] , befriends Ali Baba 's son ( who is now in charge of the late Cassim 's business ) , and is invited to dinner at Ali Baba 's house .",
#     'tags': ['O',
#      'O',
#      'O',
#      'O',
#      'B-ARGM-TMP',
#      'I-ARGM-TMP',
#      'I-ARGM-TMP',
#      'B-ARG0',
#      'I-ARG0',
#      'B-V',
#      'B-ARG1',
#      'B-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O']},
#    {'verb': 'befriends',
#     'description': "To exact revenge , after some time [ARG0: the thief] establishes himself as a merchant , [V: befriends] [ARG1: Ali Baba 's son ( who is now in charge of the late Cassim 's business )] , and is invited to dinner at Ali Baba 's house .",
#     'tags': ['O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'B-ARG0',
#      'I-ARG0',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'B-V',
#      'B-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O']},
#    {'verb': 'is',
#     'description': "To exact revenge , after some time the thief establishes himself as a merchant , [ARG1: befriends Ali Baba 's son (] [R-ARG1: who] [V: is] [ARGM-TMP: now] [ARG2: in charge of the late Cassim 's business )] , and is invited to dinner at Ali Baba 's house .",
#     'tags': ['O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'B-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'B-R-ARG1',
#      'B-V',
#      'B-ARGM-TMP',
#      'B-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O']},
#    {'verb': 'is',
#     'description': "To exact revenge , after some time the thief establishes himself as a merchant , befriends Ali Baba 's son ( who is now in charge of the late Cassim 's business ) , and [V: is] invited to dinner at Ali Baba 's house .",
#     'tags': ['O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'B-V',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O']},
#    {'verb': 'invited',
#     'description': "[ARGM-PRP: To exact revenge] , [ARGM-TMP: after some time the thief establishes himself as a merchant] , [ARG1: befriends Ali Baba 's son ( who] is now in charge of the late Cassim 's business ) , and is [V: invited] [ARG2: to dinner] [ARGM-LOC: at Ali Baba 's house] .",
#     'tags': ['B-ARGM-PRP',
#      'I-ARGM-PRP',
#      'I-ARGM-PRP',
#      'O',
#      'B-ARGM-TMP',
#      'I-ARGM-TMP',
#      'I-ARGM-TMP',
#      'I-ARGM-TMP',
#      'I-ARGM-TMP',
#      'I-ARGM-TMP',
#      'I-ARGM-TMP',
#      'I-ARGM-TMP',
#      'I-ARGM-TMP',
#      'I-ARGM-TMP',
#      'O',
#      'B-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'B-V',
#      'B-ARG2',
#      'I-ARG2',
#      'B-ARGM-LOC',
#      'I-ARGM-LOC',
#      'I-ARGM-LOC',
#      'I-ARGM-LOC',
#      'I-ARGM-LOC',
#      'O']}],
#   'words': ['To',
#    'exact',
#    'revenge',
#    ',',
#    'after',
#    'some',
#    'time',
#    'the',
#    'thief',
#    'establishes',
#    'himself',
#    'as',
#    'a',
#    'merchant',
#    ',',
#    'befriends',
#    'Ali',
#    'Baba',
#    "'s",
#    'son',
#    '(',
#    'who',
#    'is',
#    'now',
#    'in',
#    'charge',
#    'of',
#    'the',
#    'late',
#    'Cassim',
#    "'s",
#    'business',
#    ')',
#    ',',
#    'and',
#    'is',
#    'invited',
#    'to',
#    'dinner',
#    'at',
#    'Ali',
#    'Baba',
#    "'s",
#    'house',
#    '.']},
#  {'verbs': [{'verb': 'is',
#     'description': 'The thief [V: is] recognized by Morgiana , who performs a dance with a dagger for the diners and plunges it into the heart of the thief when he is off his guard .',
#     'tags': ['O',
#      'O',
#      'B-V',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O']},
#    {'verb': 'recognized',
#     'description': '[ARG1: The thief] is [V: recognized] [ARG0: by Morgiana , who performs a dance with a dagger for the diners and plunges it into the heart of the thief when he is off his guard] .',
#     'tags': ['B-ARG1',
#      'I-ARG1',
#      'O',
#      'B-V',
#      'B-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'O']},
#    {'verb': 'performs',
#     'description': 'The thief is recognized by [ARG0: Morgiana] , [R-ARG0: who] [V: performs] [ARG1: a dance] [ARGM-MNR: with a dagger] [ARGM-COM: for the diners] and plunges it into the heart of the thief when he is off his guard .',
#     'tags': ['O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'B-ARG0',
#      'O',
#      'B-R-ARG0',
#      'B-V',
#      'B-ARG1',
#      'I-ARG1',
#      'B-ARGM-MNR',
#      'I-ARGM-MNR',
#      'I-ARGM-MNR',
#      'B-ARGM-COM',
#      'I-ARGM-COM',
#      'I-ARGM-COM',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O']},
#    {'verb': 'is',
#     'description': 'The thief is recognized by Morgiana , who performs a dance with a dagger for the diners and plunges it into the heart of the thief [ARGM-TMP: when] [ARG1: he] [V: is] [ARG2: off his guard] .',
#     'tags': ['O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'B-ARGM-TMP',
#      'B-ARG1',
#      'B-V',
#      'B-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'O']}],
#   'words': ['The',
#    'thief',
#    'is',
#    'recognized',
#    'by',
#    'Morgiana',
#    ',',
#    'who',
#    'performs',
#    'a',
#    'dance',
#    'with',
#    'a',
#    'dagger',
#    'for',
#    'the',
#    'diners',
#    'and',
#    'plunges',
#    'it',
#    'into',
#    'the',
#    'heart',
#    'of',
#    'the',
#    'thief',
#    'when',
#    'he',
#    'is',
#    'off',
#    'his',
#    'guard',
#    '.']},
#  {'verbs': [{'verb': 'is',
#     'description': '[ARG1: Ali Baba] [V: is] [ARG2: at first angry with Morgiana] , but when he finds out the thief tried to kill him , he gives Morgiana her freedom and marries her to his son .',
#     'tags': ['B-ARG1',
#      'I-ARG1',
#      'B-V',
#      'B-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O']},
#    {'verb': 'finds',
#     'description': 'Ali Baba is at first angry with Morgiana , but [ARGM-TMP: when] [ARG0: he] [V: finds] out [ARG1: the thief tried to kill him] , he gives Morgiana her freedom and marries her to his son .',
#     'tags': ['O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'B-ARGM-TMP',
#      'B-ARG0',
#      'B-V',
#      'O',
#      'B-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O']},
#    {'verb': 'tried',
#     'description': 'Ali Baba is at first angry with Morgiana , but when he finds out [ARG0: the thief] [V: tried] [ARG1: to kill him] , he gives Morgiana her freedom and marries her to his son .',
#     'tags': ['O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'B-ARG0',
#      'I-ARG0',
#      'B-V',
#      'B-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O']},
#    {'verb': 'kill',
#     'description': 'Ali Baba is at first angry with Morgiana , but when he finds out [ARG0: the thief] tried to [V: kill] [ARG1: him] , he gives Morgiana her freedom and marries her to his son .',
#     'tags': ['O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'B-ARG0',
#      'I-ARG0',
#      'O',
#      'O',
#      'B-V',
#      'B-ARG1',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O']},
#    {'verb': 'gives',
#     'description': 'Ali Baba is at first angry with Morgiana , but [ARGM-TMP: when he finds out the thief tried to kill him] , [ARG0: he] [V: gives] [ARG2: Morgiana] [ARG1: her freedom] and marries her to his son .',
#     'tags': ['O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'B-ARGM-TMP',
#      'I-ARGM-TMP',
#      'I-ARGM-TMP',
#      'I-ARGM-TMP',
#      'I-ARGM-TMP',
#      'I-ARGM-TMP',
#      'I-ARGM-TMP',
#      'I-ARGM-TMP',
#      'I-ARGM-TMP',
#      'I-ARGM-TMP',
#      'O',
#      'B-ARG0',
#      'B-V',
#      'B-ARG2',
#      'B-ARG1',
#      'I-ARG1',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O']},
#    {'verb': 'marries',
#     'description': 'Ali Baba is at first angry with Morgiana , but [ARGM-TMP: when he finds out the thief tried to kill him] , [ARG1: he] gives Morgiana her freedom and [V: marries] [ARG2: her] [ARGM-GOL: to his son] .',
#     'tags': ['O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'B-ARGM-TMP',
#      'I-ARGM-TMP',
#      'I-ARGM-TMP',
#      'I-ARGM-TMP',
#      'I-ARGM-TMP',
#      'I-ARGM-TMP',
#      'I-ARGM-TMP',
#      'I-ARGM-TMP',
#      'I-ARGM-TMP',
#      'I-ARGM-TMP',
#      'O',
#      'B-ARG1',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'B-V',
#      'B-ARG2',
#      'B-ARGM-GOL',
#      'I-ARGM-GOL',
#      'I-ARGM-GOL',
#      'O']}],
#   'words': ['Ali',
#    'Baba',
#    'is',
#    'at',
#    'first',
#    'angry',
#    'with',
#    'Morgiana',
#    ',',
#    'but',
#    'when',
#    'he',
#    'finds',
#    'out',
#    'the',
#    'thief',
#    'tried',
#    'to',
#    'kill',
#    'him',
#    ',',
#    'he',
#    'gives',
#    'Morgiana',
#    'her',
#    'freedom',
#    'and',
#    'marries',
#    'her',
#    'to',
#    'his',
#    'son',
#    '.']},
#  {'verbs': [{'verb': 'is',
#     'description': 'Ali Baba [V: is] then left as the only one knowing the secret of the treasure in the cave and how to access it .',
#     'tags': ['O',
#      'O',
#      'B-V',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O']},
#    {'verb': 'left',
#     'description': '[ARG0: Ali Baba] is [ARGM-TMP: then] [V: left] [ARG1: as the only one knowing the secret of the treasure in the cave and how to access it] .',
#     'tags': ['B-ARG0',
#      'I-ARG0',
#      'O',
#      'B-ARGM-TMP',
#      'B-V',
#      'B-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'O']},
#    {'verb': 'knowing',
#     'description': 'Ali Baba is then left as [ARG0: the only one] [V: knowing] [ARG1: the secret of the treasure in the cave and how to access it] .',
#     'tags': ['O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'B-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'B-V',
#      'B-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'O']},
#    {'verb': 'access',
#     'description': 'Ali Baba is then left as the only one knowing the secret of the treasure in the cave and [ARGM-MNR: how] to [V: access] [ARG1: it] .',
#     'tags': ['O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'B-ARGM-MNR',
#      'O',
#      'B-V',
#      'B-ARG1',
#      'O']}],
#   'words': ['Ali',
#    'Baba',
#    'is',
#    'then',
#    'left',
#    'as',
#    'the',
#    'only',
#    'one',
#    'knowing',
#    'the',
#    'secret',
#    'of',
#    'the',
#    'treasure',
#    'in',
#    'the',
#    'cave',
#    'and',
#    'how',
#    'to',
#    'access',
#    'it',
#    '.']},
#  {'verbs': [{'verb': 'ends',
#     'description': '[ARGM-DIS: Thus] , [ARG1: the story] [V: ends] [ARGM-MNR: happily] [ARGM-ADV: for everyone except the forty thieves and Cassim] .',
#     'tags': ['B-ARGM-DIS',
#      'O',
#      'B-ARG1',
#      'I-ARG1',
#      'B-V',
#      'B-ARGM-MNR',
#      'B-ARGM-ADV',
#      'I-ARGM-ADV',
#      'I-ARGM-ADV',
#      'I-ARGM-ADV',
#      'I-ARGM-ADV',
#      'I-ARGM-ADV',
#      'I-ARGM-ADV',
#      'I-ARGM-ADV',
#      'O']}],
#   'words': ['Thus',
#    ',',
#    'the',
#    'story',
#    'ends',
#    'happily',
#    'for',
#    'everyone',
#    'except',
#    'the',
#    'forty',
#    'thieves',
#    'and',
#    'Cassim',
#    '.']}]

# %%
sentences_df = pd.read_csv('ali-baba-and-forty-thieves.sentences.csv')
sentences = sentences_df['text'].to_list()
sentences
# Out:
# ['The story takes place in Baghdad during the Abbasid era. ',
#  'Ali Baba and his elder brother Cassim are the sons of a merchant. ',
#  "After the death of their father, the greedy Cassim marries a wealthy woman and becomes well-to-do, building on their father's business - but Ali Baba marries a poor woman and settles into the trade of a woodcutter. ",
#  'One day Ali Baba is at work collecting and cutting firewood in the forest, and he happens to overhear a group of forty thieves visiting their treasure store. ',
#  'The treasure is in a cave, the mouth of which is sealed by magic. ',
#  'It opens on the words "Open, Simsim", and seals itself on the words "Close, Simsim". ',
#  'When the thieves are gone, Ali Baba enters the cave himself, and takes some of the treasure home. ',
#  "Ali Baba borrows his sister-in-law's scales to weigh this new wealth of gold coins. ",
#  'Unbeknownst to Ali, she puts a blob of wax in the scales to find out what Ali is using them for, as she is curious to know what kind of grain her impoverished brother-in-law needs to measure. ',
#  "To her shock, she finds a gold coin sticking to the scales and tells her husband, Ali Baba's rich and greedy brother, Cassim. ",
#  'Under pressure from his brother, Ali Baba is forced to reveal the secret of the cave. ',
#  'Cassim goes to the cave and enters with the magic words, but in his greed and excitement over the treasures forgets the magic words to get back out again. ',
#  'The thieves find him there, and kill him. ',
#  'When his brother does not come back, Ali Baba goes to the cave to look for him, and finds the body, quartered and with each piece displayed just inside the entrance of the cave to discourage any similar attempts in the future. ',
#  "Ali Baba brings the body home, where he entrusts Morgiana, a clever slave-girl in Cassim's household, with the task of making others believe that Cassim has died a natural death. ",
#  "First, Morgiana purchases medicines from an apothecary, telling him that Cassim is gravely ill. Then, she finds an old tailor known as Baba Mustafa whom she pays, blindfolds, and leads to Cassim's house. ",
#  "There, overnight, the tailor stitches the pieces of Cassims' body back together, so that no one will be suspicious. ",
#  'Ali and his family are able to give Cassim a proper burial without anyone asking awkward questions. ',
#  'The thieves, finding the body gone, realize that yet another person must know their secret, and set out to track him down. ',
#  "One of the thieves goes down to the town and comes across Baba Mustafa, who mentions that he has just sewn a dead man's body back together. ",
#  "Realizing that the dead man must have been the thieves' victim, the thief asks Baba Mustafa to lead the way to the house where the deed was performed. ",
#  'The tailor is blindfolded again, and in this state he is able to retrace his steps and find the house. ',
#  'The thief marks the door with a symbol. ',
#  'The plan is for the other thieves to come back that night and kill everyone in the house. ',
#  'However, the thief has been seen by Morgiana and she, loyal to her master, foils his plan by marking all the houses in the neighborhood with a similar marking. ',
#  'When the 40 thieves return that night, they cannot identify the correct house and the head thief kills the lesser thief. ',
#  "The next day, another thief revisits Baba Mustafa and tries again, only this time, a chunk is chipped out of the stone step at Ali Baba's front door. ",
#  'Again Morgiana foils the plan by making similar chips in all the other doorsteps. ',
#  'The second thief is killed for his stupidity as well. ',
#  'At last, the head thief goes and looks for himself. ',
#  "This time, he memorizes every detail he can of the exterior of Ali Baba's house. ",
#  "The chief of the thieves pretends to be an oil merchant in need of Ali Baba's hospitality, bringing with him Forty thieves hiding in oil jarsmules loaded with thirty-eight oil jars, one filled with oil, the other thirty-seven hiding the other remaining thieves. ",
#  'Once Ali Baba is asleep, the thieves plan to kill him. ',
#  'Again, Morgiana discovers and foils the plan, killing the thirty-seven thieves in their oil jars by pouring boiling oil on them. ',
#  'When their leader comes to rouse his men, he discovers that they are dead, and escapes. ',
#  "To exact revenge, after some time the thief establishes himself as a merchant, befriends Ali Baba's son (who is now in charge of the late Cassim's business), and is invited to dinner at Ali Baba's house. ",
#  'The thief is recognized by Morgiana, who performs a dance with a dagger for the diners and plunges it into the heart of the thief when he is off his guard. ',
#  'Ali Baba is at first angry with Morgiana, but when he finds out the thief tried to kill him, he gives Morgiana her freedom and marries her to his son. ',
#  'Ali Baba is then left as the only one knowing the secret of the treasure in the cave and how to access it. ',
#  'Thus, the story ends happily for everyone except the forty thieves and Cassim.']
