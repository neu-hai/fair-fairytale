# %%
import pandas as pd
event_coref = pd.read_csv('ali-baba-and-forty-thieves.verb_subj_dobj.srl.csv')
event_coref
# Out:
#      sentence_id  verb_id      verb  verb_start_byte  verb_end_byte  \
# 0              1        0       are               38             41
# 1              2        0   marries               51             58
# 2              2        1   becomes               79             86
# 3              2        2  building               99            107
# 4              2        3   marries              150            157
# ..           ...      ...       ...              ...            ...
# 107           37        2     tried               74             79
# 108           37        3      kill               83             87
# 109           37        4     gives               96            101
# 110           37        5   marries              127            134
# 111           38        1      left               17             21
#
#      verb_start_byte_text  verb_end_byte_text subj_coref_ids  subj_start_byte  \
# ...

# %%
event_coref.iloc[2]['dobj_coref_ids']
# Out:
# nan

# %%
event_coref.loc[event_coref['subj_coref_ids'].isnull()==False]
# Out:
#      sentence_id  verb_id      verb  verb_start_byte  verb_end_byte  \
# 0              1        0       are               38             41
# 1              2        0   marries               51             58
# 2              2        1   becomes               79             86
# 3              2        2  building               99            107
# 4              2        3   marries              150            157
# ..           ...      ...       ...              ...            ...
# 107           37        2     tried               74             79
# 108           37        3      kill               83             87
# 109           37        4     gives               96            101
# 110           37        5   marries              127            134
# 111           38        1      left               17             21
#
#      verb_start_byte_text  verb_end_byte_text subj_coref_ids  subj_start_byte  \
# ...

# %%
event_coref.iloc[:30]
# Out:
#     sentence_id  verb_id        verb  verb_start_byte  verb_end_byte  \
# 0             1        0         are               38             41
# 1             2        0     marries               51             58
# 2             2        1     becomes               79             86
# 3             2        2    building               99            107
# 4             2        3     marries              150            157
# 5             2        4     settles              175            182
# 6             3        0          is               17             19
# 7             3        1  collecting               28             38
# 8             3        3     happens               82             89
# 9             3        4    overhear               93            101
# 10            5        0       opens                3              8
# 11            5        1       seals               42             47
# 12            6        1        gone               21             25
# ...

# %%
import pandas as pd
technologies = {
    'Courses':["Spark","PySpark","Hadoop","Python","pandas"],
    'Fee' :[20000,25000,26000,22000,24000],
    'Duration':['30day','40days','35days','40days','60days'],
    'Discount':[1000,2300,1200,2500,2000]
              }
index_labels=['r1','r2','r3','r4','r5']
df = pd.DataFrame(technologies,index=index_labels)
print(df)
# Out:
#     Courses    Fee Duration  Discount
# r1    Spark  20000    30day      1000
# r2  PySpark  25000   40days      2300
# r3   Hadoop  26000   35days      1200
# r4   Python  22000   40days      2500
# r5   pandas  24000   60days      2000

# %%
df2=df.loc[(df['Discount'] >= 20000) | (df['Fee'] >= 23000 )]
print(df2)
# Out:
#     Courses    Fee Duration  Discount
# r2  PySpark  25000   40days      2300
# r3   Hadoop  26000   35days      1200
# r5   pandas  24000   60days      2000

# %%
import pandas as pd
super_df = pd.read_csv('ali-baba-and-forty-thieves.supersense', sep=',')
super_df.iloc[:30]
# Out:
#     start_token  end_token supersense_category          text  StartByte  \
# 0             1          1  noun.communication         story          4
# 1             2          3         verb.change   takes place         10
# 2             5          5       noun.location       Baghdad         25
# 3             9          9           noun.time           era         52
# 4            11         12         noun.person      Ali Baba         57
# 5            16         16         noun.person       brother         80
# 6            17         17         noun.person        Cassim         88
# 7            18         18        verb.stative           are         95
# 8            20         20         noun.person          sons        103
# 9            23         23         noun.person      merchant        113
# 10           27         27          noun.event         death        133
# 11           30         30         noun.person        father        148
# ...

# %%
event_coref.loc[(event_coref['sentence_id'] == 10) & (event_coref['verb_id'] == 1)]
# Out:
#     sentence_id  verb_id    verb  verb_start_byte  verb_end_byte  \
# 26           10        1  forced               45             51
#
#     verb_start_byte_text  verb_end_byte_text subj_coref_ids  subj_start_byte  \
# 26                  1192                1198           1,28              0.0
#
#     subj_end_byte  subj_start_byte_text  subj_end_byte_text dobj_coref_ids  \
# 26           41.0                1147.0              1188.0            NaN
#
#     dobj_start_byte  dobj_end_byte  dobj_start_byte_text  dobj_end_byte_text
# 26             52.0           84.0                1199.0              1231.0

# %%
event_coref.iloc[:30]
# Out:
#     sentence_id  verb_id        verb  verb_start_byte  verb_end_byte  \
# 0             1        0         are               38             41
# 1             2        0     marries               51             58
# 2             2        1     becomes               79             86
# 3             2        2    building               99            107
# 4             2        3     marries              150            157
# 5             2        4     settles              175            182
# 6             3        0          is               17             19
# 7             3        1  collecting               28             38
# 8             3        3     happens               82             89
# 9             3        4    overhear               93            101
# 10            5        0       opens                3              8
# 11            5        1       seals               42             47
# 12            6        1        gone               21             25
# ...

# %%
srl=pd.read_json("ali-baba-and-forty-thieves/ali-baba-and-forty-thieves.srl.json")
srl
# Out:
#                                                 verbs  \
# 0   [{'verb': 'takes', 'description': '[ARG1: The ...
# 1   [{'verb': 'are', 'description': '[ARG1: Ali Ba...
# 2   [{'verb': 'marries', 'description': '[ARGM-TMP...
# 3   [{'verb': 'is', 'description': '[ARG1: One day...
# 4   [{'verb': 'is', 'description': '[ARG1: The tre...
# 5   [{'verb': 'opens', 'description': '[ARG2: It] ...
# 6   [{'verb': 'are', 'description': 'When the thie...
# 7   [{'verb': 'borrows', 'description': '[ARG0: Al...
# 8   [{'verb': 'puts', 'description': '[R-ARG0: Unb...
# 9   [{'verb': 'finds', 'description': '[R-ARG0: To...
# 10  [{'verb': 'is', 'description': 'Under pressure...
# 11  [{'verb': 'goes', 'description': '[ARG1: Cassi...
# 12  [{'verb': 'find', 'description': '[ARG0: The t...
# 13  [{'verb': 'does', 'description': 'When his bro...
# 14  [{'verb': 'brings', 'description': '[ARG0: Ali...
# 15  [{'verb': 'purchases', 'description': '[ARGM-D...
# ...

# %%
event_coref.iloc[0]['verb_start_byte']-1
# Out:
# 37
